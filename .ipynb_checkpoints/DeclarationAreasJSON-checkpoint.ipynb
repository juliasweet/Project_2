# %% [markdown]
# # Data Cleaning 3
#
# ### Cleaning the JSON file.
#
# Source: https://www.fema.gov/api/open/v1/FemaWebDeclarationAreas
#
# JSON file was taken from above URL.

# %%
# Import dependencies
import json
import pandas as pd

# %%
# Read in file.
FEMA_areas_data = pd.read_json('FEMAareas.json')

# %%
# Look at headings
FEMA_areas_data.head()
# Out:
#                closeoutDate            designatedDate  disasterNumber  \
# 0                       NaN  2013-06-25T00:00:00.000Z            4122
# 1                       NaN  2013-06-25T00:00:00.000Z            4122
# 2                       NaN  2012-11-28T00:00:00.000Z            4094
# 3  1997-12-16T00:00:00.000Z  1989-05-10T00:00:00.000Z             826
# 4  1997-12-16T00:00:00.000Z  1989-05-10T00:00:00.000Z             826
#
#                   entryDate                              hash  \
# 0  2013-06-25T00:00:00.000Z  93ef5733b3a00b7e27b5dd7005435a35
# 1  2013-06-25T00:00:00.000Z  78cf589fa42c07e610fecfdf41a62542
# 2  2012-11-28T00:00:00.000Z  617692ae23ed75b1f9e6b24539253fe8
# 3  1993-07-25T00:00:00.000Z
# 4  1993-07-25T00:00:00.000Z
#
#                          id               lastRefresh  placeCode  \
# 0  5aa2d0e8cb4f0f7020abed71  2018-03-09T18:22:32.135Z       1255
# 1  5aa2d0e8cb4f0f7020abed7d  2018-03-09T18:22:32.153Z       1255
# 2  5aa2d0e8cb4f0f7020abed7e  2018-03-09T18:22:32.154Z       1255
# 3  5aa2d0e8cb4f0f7020abed79  2019-07-02T19:07:06.946Z       1580
# 4  5aa2d0e8cb4f0f7020abed83  2019-07-02T19:07:06.965Z       1580
#
#                                            placeName programTypeCode  \
# 0  Alaska Gateway Regional Educational Attendance...              PA
# 1  Alaska Gateway Regional Educational Attendance...              IH
# 2  Alaska Gateway Regional Educational Attendance...            PA-C
# 3                  Aleutian Islands (Census Subarea)            PA-B
# 4                  Aleutian Islands (Census Subarea)            PA-A
#
#               programTypeDescription stateCode  \
# 0             PA - Public Assistance        AK
# 1  IH - IHP-Individuals & Households        AK
# 2             PA-C - Roads & Bridges        AK
# 3         PA-B - Protective Measures        AK
# 4              PA-A - Debris Removal        AK
#
#                         stateName                updateDate
# 0  Alaska                          2013-06-25T00:00:00.000Z
# 1  Alaska                          2013-06-25T00:00:00.000Z
# 2  Alaska                          2012-11-28T00:00:00.000Z
# 3  Alaska                          1993-07-25T00:00:00.000Z
# 4  Alaska                          1993-07-25T00:00:00.000Z

# %% [markdown]
# ### PostgreSQL table needs only disasterNumber, programTypeCode, programTypeDescription, stateCode, placeCode, and designatedDate. Create a new DF with only those columns.

# %%
declarationAreas = FEMA_areas_data[['disasterNumber', 'programTypeCode',
                                'programTypeDescription', 'stateCode',
                                'placeCode', 'designatedDate']].copy()

# %%
declarationAreas.head()
# Out:
#    disasterNumber programTypeCode             programTypeDescription  \
# 0            4122              PA             PA - Public Assistance
# 1            4122              IH  IH - IHP-Individuals & Households
# 2            4094            PA-C             PA-C - Roads & Bridges
# 3             826            PA-B         PA-B - Protective Measures
# 4             826            PA-A              PA-A - Debris Removal
#
#   stateCode  placeCode            designatedDate
# 0        AK       1255  2013-06-25T00:00:00.000Z
# 1        AK       1255  2013-06-25T00:00:00.000Z
# 2        AK       1255  2012-11-28T00:00:00.000Z
# 3        AK       1580  1989-05-10T00:00:00.000Z
# 4        AK       1580  1989-05-10T00:00:00.000Z

# %%
# Check data types. 
print(declarationAreas.dtypes)
# Out:
# disasterNumber             int64
# programTypeCode           object
# programTypeDescription    object
# stateCode                 object
# placeCode                  int64
# designatedDate            object
# dtype: object

# %% [markdown]
# ### Remove hour:minute:second:timezone

# %%
declarationAreas['designatedDate'] = declarationAreas['designatedDate'].str.replace('T00:00:00.000Z', '')

# %%
declarationAreas.head(15)
# Out:
#     disasternumber programtypecode               programtypedescription  \
# 0             4122              PA               PA - Public Assistance
# 1             4122              IH    IH - IHP-Individuals & Households
# 2             4094            PA-C               PA-C - Roads & Bridges
# 3              826            PA-B           PA-B - Protective Measures
# 4              826            PA-A                PA-A - Debris Removal
# 5             4122            PA-G         PA-G - Recreational or Other
# 6             4094            PA-D      PA-D - Water Control Facilities
# 7              826            PA-G         PA-G - Recreational or Other
# 8              826            PA-F              PA-F - Public Utilities
# 9             1843              PA               PA - Public Assistance
# 10            4122              HA              HA - Housing Assistance
# 11            4122              CC               CC - Crisis Counseling
# 12            1843            PA-B           PA-B - Protective Measures
# 13            4122            PA-C               PA-C - Roads & Bridges
# 14            1843             DUA  DUA - Disaster Unemployment Assist.
#
#    statecode  placecode designateddate
# 0         AK       1255     2013-06-25
# 1         AK       1255     2013-06-25
# 2         AK       1255     2012-11-28
# 3         AK       1580     1989-05-10
# 4         AK       1580     1989-05-10
# 5         AK       1255     2013-06-25
# 6         AK       1255     2012-11-28
# 7         AK       1580     1989-05-10
# 8         AK       1580     1989-05-10
# 9         AK       1255     2009-06-11
# 10        AK       1255     2013-06-25
# 11        AK       1255     2013-06-25
# 12        AK       1255     2009-06-11
# 13        AK       1255     2013-06-25
# 14        AK       1255     2009-06-11

# %% [markdown]
# ### Make columns lowercase

# %%
declarationAreas = declarationAreas.rename(columns={'disasterNumber': 'disasternumber', 'programTypeCode': 'programtypecode',
                                                   'programTypeDescription':'programtypedescription', 'stateCode':'statecode',
                                                   'placeCode':'placecode', 'designatedDate':'designateddate'})

# %% [markdown]
# # Export to PostgreSQL

# %%
from sqlalchemy import create_engine

# %%
conn = conn = "postgres:Project2@localhost:5432/Project_2"
engine = create_engine((f'postgresql://{conn}'))

# %%
engine.table_names()
# Out:
# ['disasterdeclarations', 'disastersummaries', 'declarationareas']

# %%
declarationAreas.to_sql(name='declarationareas', con=engine, if_exists='append', index=False)

# %%
pd.read_sql_query('select * from declarationareas', con=engine).head()
# Out:
#    disasternumber programtypecode             programtypedescription  \
# 0            4122              PA             PA - Public Assistance
# 1            4122              IH  IH - IHP-Individuals & Households
# 2            4094            PA-C             PA-C - Roads & Bridges
# 3             826            PA-B         PA-B - Protective Measures
# 4             826            PA-A              PA-A - Debris Removal
#
#   statecode  placecode designateddate
# 0        AK       1255     2013-06-25
# 1        AK       1255     2013-06-25
# 2        AK       1255     2012-11-28
# 3        AK       1580     1989-05-10
# 4        AK       1580     1989-05-10
