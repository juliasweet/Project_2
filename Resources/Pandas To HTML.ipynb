# %%
import pandas as pd

# %%
weather_data = "C:\\Users\\kjyou\\Git\\Bootcamp\\Web Visualization Dashboard (Latitude)\Resources\weather_data.csv"

# %%
weather_df = pd.read_csv(weather_data, encoding="utf-8")

# %%
weather_df = weather_df.drop(['Unnamed: 0'], axis=1)

# %%
weather_df.head()
# Out:
#                 City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0            Mataura          52      NZ  1562819251        83 -46.19  168.86
# 1  Sao Joao da Barra           0      BR  1562819253        90 -21.64  -41.05
# 2                Hit           0      IQ  1562819255        31  33.64   42.83
# 3           Portland          90      US  1562818983        77  43.66  -70.25
# 4             Noumea           0      NC  1562819089        64 -22.28  166.46
#
#    Max Temp  Wind Speed
# 0     52.00        3.00
# 1     58.22        1.39
# 2     83.91       17.94
# 3     64.40        3.36
# 4     73.40        8.05

# %%
# render dataframe as html
html = weather_df.to_html()
print(html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Cloudiness</th>
#       <th>Country</th>
#       <th>Date</th>
#       <th>Humidity</th>
#       <th>Lat</th>
#       <th>Lng</th>
#       <th>Max Temp</th>
#       <th>Wind Speed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Mataura</td>
#       <td>52</td>
#       <td>NZ</td>
#       <td>1562819251</td>
#       <td>83</td>
#       <td>-46.19</td>
#       <td>168.86</td>
#       <td>52.00</td>
#       <td>3.00</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Sao Joao da Barra</td>
#       <td>0</td>
#       <td>BR</td>
#       <td>1562819253</td>
#       <td>90</td>
#       <td>-21.64</td>
#       <td>-41.05</td>
#       <td>58.22</td>
#       <td>1.39</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Hit</td>
#       <td>0</td>
#       <td>IQ</td>
#       <td>1562819255</td>
# ...
